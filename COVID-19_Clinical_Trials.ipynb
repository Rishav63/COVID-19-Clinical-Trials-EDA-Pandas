# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'/Users/rishavkumarsharma/Downloads/COVID clinical trials.csv')

# %%
data.head(10)
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 5     6  NCT04516954          Convalescent Plasma for COVID-19 Patients
# 6     7  NCT04476940  COVID-19 Breastfeeding Guideline for African-A...
# 7     8  NCT04634214  The Severity of COVID 19 in Diabetes and Non-d...
# 8     9  NCT04602884  Early Detection of COVID-19 Using Breath Analysis
# 9    10  NCT04384588  COVID19-Convalescent Plasma for Treating Patie...
#
#         Acronym                   Status         Study Results  \
# 0   COVID-IDNow   Active, not recruiting  No Results Available
# ...

# %%
data.shape
# Out:
# (5783, 27)

# %%
data.describe(include ='all')
# Out:
#                Rank   NCT Number  \
# count   5783.000000         5783
# unique          NaN         5783
# top             NaN  NCT04785898
# freq            NaN            1
# mean    2892.000000          NaN
# std     1669.552635          NaN
# min        1.000000          NaN
# 25%     1446.500000          NaN
# 50%     2892.000000          NaN
# 75%     4337.500000          NaN
# max     5783.000000          NaN
#
#                                                     Title   Acronym  \
# count                                                5783      2480
# unique                                               5775      2338
# top     Study Assessing Vagus Nerve Stimulation in CoV...  COVID-19
# freq                                                    2        47
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
# Categorical Features
data.select_dtypes(include = 'object').columns
# Out:
# Index(['NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Funded Bys',
#        'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Results First Posted', 'Last Update Posted', 'Locations',
#        'Study Documents', 'URL'],
#       dtype='object')

# %%
# Numerical Features
data.select_dtypes(include = 'int').columns
# Out:
# Index(['Rank'], dtype='object')

# %%
# Numerical Features
data.select_dtypes(include = float).columns
# Out:
# Index(['Enrollment'], dtype='object')

# %%
# Detecting (Percentage) Missing Data
missing_data = data.isnull().mean() * 100
missing_data
# Out:
# Rank                        0.000000
# NCT Number                  0.000000
# Title                       0.000000
# Acronym                    57.115684
# Status                      0.000000
# Study Results               0.000000
# Conditions                  0.000000
# Interventions              15.320768
# Outcome Measures            0.605222
# Sponsor/Collaborators       0.000000
# Gender                      0.172921
# Age                         0.000000
# Phases                     42.555767
# Enrollment                  0.587930
# Funded Bys                  0.000000
# Study Type                  0.000000
# Study Designs               0.605222
# Other IDs                   0.017292
# Start Date                  0.587930
# Primary Completion Date     0.622514
# Completion Date             0.622514
# First Posted                0.000000
# Results First Posted       99.377486
# Last Update Posted          0.000000
# Locations                  10.115857
# ...

# %%
x=data['Enrollment'].median()
y=data['Enrollment'].mode()
z=data['Enrollment'].std()

print(x)
print(y)
print(z)
# Out:
# 170.0
# 0    100.0
# Name: Enrollment, dtype: float64
# 404543.7287841073

# %% [markdown]
# ### **Dataset Overview**
# - The dataset consists of 5783 entries and 27 columns. Below is a summary of the key columns and their descriptions:
#
# **Column Analysis**
# - **Rank, NCT Number, Title:** Metadata for each trial.
# - **Acronym:** Missing for 57% of rows; categorical.
# - **Status:** Contains 12 unique statuses like "Recruiting", "Completed", etc.
# - **Study Results, Conditions, Interventions, Outcome Measures:** Provide detailed information about each trial.
# - **Sponsor/Collaborators, Gender, Age:** Additional details about participants and sponsors.
# - **Phases:** Missing for 42% of rows; defines trial phases.
# - **Enrollment:** Numeric, missing for 0.6% of rows; highly skewed.
# - **Dates:** Includes Start Date, Primary Completion Date, and Completion Date.
# - **Locations, Study Documents:** Location data is partially missing (10%), and Study Documents has significant missingness (96.8%).
# - **URL:** Unique for every trial.

# %%
data['Enrollment'] = data['Enrollment'].fillna(data['Enrollment'].median())

# %%
data.drop(columns=['Results First Posted','Study Documents'],inplace=True)

# %%
# Detecting (Percentage) Missing Data
missing_data = data.isnull().mean() * 100
missing_data
# Out:
# Rank                        0.000000
# NCT Number                  0.000000
# Title                       0.000000
# Acronym                    57.115684
# Status                      0.000000
# Study Results               0.000000
# Conditions                  0.000000
# Interventions              15.320768
# Outcome Measures            0.605222
# Sponsor/Collaborators       0.000000
# Gender                      0.172921
# Age                         0.000000
# Phases                     42.555767
# Enrollment                  0.000000
# Funded Bys                  0.000000
# Study Type                  0.000000
# Study Designs               0.605222
# Other IDs                   0.017292
# Start Date                  0.587930
# Primary Completion Date     0.622514
# Completion Date             0.622514
# First Posted                0.000000
# Last Update Posted          0.000000
# Locations                  10.115857
# URL                         0.000000
# dtype: float64

# %%
print(f"Shape before dropping Null rows {data.shape}")
data.dropna(axis = 0 , thresh = 10 , inplace = True)
print(f"Shape after dropping Null rows {data.shape}")
# Out:
# Shape before dropping Null rows (5783, 25)
# Shape after dropping Null rows (5783, 25)

# %%
data.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                    0
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Last Update Posted            0
# Locations                   585
# URL                           0
# dtype: int64

# %%
data.isnull().mean() * 100
# Out:
# Rank                        0.000000
# NCT Number                  0.000000
# Title                       0.000000
# Acronym                    57.115684
# Status                      0.000000
# Study Results               0.000000
# Conditions                  0.000000
# Interventions              15.320768
# Outcome Measures            0.605222
# Sponsor/Collaborators       0.000000
# Gender                      0.172921
# Age                         0.000000
# Phases                     42.555767
# Enrollment                  0.000000
# Funded Bys                  0.000000
# Study Type                  0.000000
# Study Designs               0.605222
# Other IDs                   0.017292
# Start Date                  0.587930
# Primary Completion Date     0.622514
# Completion Date             0.622514
# First Posted                0.000000
# Last Update Posted          0.000000
# Locations                  10.115857
# URL                         0.000000
# dtype: float64

# %%
# Impute missing values for numerical features
numerical_features = data.select_dtypes(include="int").columns

# %%
print("\nColumns with missing values (before imputation):")
print(data[numerical_features].isnull().sum())
# Out:
# Columns with missing values (before imputation):
# Rank    0
# dtype: int64

# %%
for feature in numerical_features:
    if data[feature].isnull().sum() > 0:
        data[feature] = data[feature].fillna(df[feature].median())

# %%
print("\nColumns with missing values (after imputation):")
print(data[numerical_features].isnull().sum())
# Out:
# Columns with missing values (after imputation):
# Rank    0
# dtype: int64

# %%
# Impute missing values for Categorical features
categorical_features = data.select_dtypes(include="object").columns

# %%
print("\nColumns with missing values (before imputation):")
print(data[categorical_features].isnull().sum())
# Out:
# Columns with missing values (before imputation):
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Last Update Posted            0
# Locations                   585
# URL                           0
# dtype: int64

# %%
for feature in categorical_features:
    if data[feature].isnull().sum() > 0:
        data[feature] = data[feature].fillna(f"Missing {feature}")

# %%
print("\nColumns with missing values (after imputation):")
print(data[categorical_features].isnull().sum())
# Out:
# Columns with missing values (after imputation):
# NCT Number                 0
# Title                      0
# Acronym                    0
# Status                     0
# Study Results              0
# Conditions                 0
# Interventions              0
# Outcome Measures           0
# Sponsor/Collaborators      0
# Gender                     0
# Age                        0
# Phases                     0
# Funded Bys                 0
# Study Type                 0
# Study Designs              0
# Other IDs                  0
# Start Date                 0
# Primary Completion Date    0
# Completion Date            0
# First Posted               0
# Last Update Posted         0
# Locations                  0
# URL                        0
# dtype: int64

# %%
sns.countplot(x='Gender', data=data, palette = 'bright', hue= 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=data, x='Status', order=data['Status'].value_counts().index, palette='bright', hue='Status')
plt.title('Distribution of Study Status', fontsize=10, fontweight='bold')
plt.xlabel('Status', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=80, fontsize=8)  
plt.yticks(fontsize=8)
plt.show()

# %%
sns.countplot(data=data, x='Phases', order=data['Phases'].value_counts().index, palette='coolwarm', hue='Phases')
plt.title('Distribution of Study Phases', fontsize=10, fontweight='bold')
plt.xlabel('Phases', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=65, fontsize=8)
plt.show()

# %%
data['Study Type'].value_counts()
# Out:
# Study Type
# Interventional                                                         3322
# Observational                                                          2427
# Expanded Access:Intermediate-size Population                             15
# Expanded Access:Treatment IND/Protocol                                    8
# Expanded Access:Intermediate-size Population|Treatment IND/Protocol       5
# Expanded Access:Individual Patients                                       3
# Expanded Access:Individual Patients|Intermediate-size Population          1
# Expanded Access                                                           1
# Expanded Access:Individual Patients|Treatment IND/Protocol                1
# Name: count, dtype: int64

# %%
data['Study Type'].value_counts().sort_values(ascending=True).plot(kind='barh')
plt.title('Distribution of Study Type', fontsize=10, fontweight='bold')
plt.xlabel('Count', fontsize=10)
plt.ylabel('Study Type', fontsize=10)
plt.xticks(fontsize=8)
plt.show()

# %%
data['Phases'].value_counts().sort_values(ascending=True).plot(kind='barh',color='red')
plt.title('Distribution of Phases', fontsize=10, fontweight='bold')
plt.xlabel('Phases', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(fontsize=8)
plt.show()

# %%
data['Gender'].value_counts()
# Out:
# Gender
# All               5567
# Female             162
# Male                44
# Missing Gender      10
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 18 Years and older   (Adult, Older Adult)           2885
# Child, Adult, Older Adult                            486
# 18 Years to 80 Years   (Adult, Older Adult)          221
# 18 Years to 65 Years   (Adult, Older Adult)          155
# 18 Years to 75 Years   (Adult, Older Adult)          135
#                                                     ...
# 15 Years to 45 Years   (Child, Adult)                  1
# 1 Month to 30 Years   (Child, Adult)                   1
# 21 Years to 40 Years   (Adult)                         1
# 11 Years and older   (Child, Adult, Older Adult)       1
# 8 Years to 20 Years   (Child, Adult)                   1
# Name: count, Length: 417, dtype: int64

# %%
def extract_age_range(age):
    if 'Years to' in age:
        age_range = age.split(' to ')
        return int(age_range[0].split(' ')[0]), int(age_range[1].split(' ')[0])
    
    elif 'and older' in age:
        min_age = int(age.split(' ')[0])
        return min_age, np.inf 
    
    elif 'Child' in age:
        return 0, 18  
    elif 'Adult' in age:
        return 18, 65  
    elif 'Older Adult' in age:
        return 65, 100 
    else:
        return np.nan, np.nan  

data[['Age_min', 'Age_max']] = data['Age'].apply(lambda x: pd.Series(extract_age_range(x)))
print(data[['Age', 'Age_min', 'Age_max']].head(10))
# Out:
#                                                 Age  Age_min  Age_max
# 0         18 Years and older   (Adult, Older Adult)     18.0      inf
# 1         18 Years and older   (Adult, Older Adult)     18.0      inf
# 2         18 Years and older   (Adult, Older Adult)     18.0      inf
# 3                         Child, Adult, Older Adult      0.0     18.0
# 4                    18 Years to 48 Years   (Adult)     18.0     48.0
# 5       18 Years to 75 Years   (Adult, Older Adult)     18.0     75.0
# 6                    18 Years to 45 Years   (Adult)     18.0     45.0
# 7       18 Years to 99 Years   (Adult, Older Adult)     18.0     99.0
# 8                    18 Years to 55 Years   (Adult)     18.0     55.0
# 9  15 Years and older   (Child, Adult, Older Adult)     15.0      inf

# %%
bins = [0, 18, 35, 60, 100]  
labels = ['Child', 'Adolescent', 'Adult', 'Senior']

data['Age Category'] = pd.cut(data['Age_min'], bins=bins, labels=labels, right=False)
print(data['Age Category'].value_counts())

plt.figure(figsize=(6, 4))
sns.countplot(x=data['Age Category'], palette='bright')
plt.title('Distribution of Age Categories in Clinical Trials', fontsize=16)
plt.xlabel('Age Category', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Age Category
# Adolescent    4525
# Child         1008
# Adult          133
# Senior         116
# Name: count, dtype: int64
# /var/folders/v0/87_rm9fx26qgc2ffgmn71pqc0000gn/T/ipykernel_3271/4230206594.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Age Category'], palette='bright')

# %%
data['Study Results'].value_counts()
# Out:
# Study Results
# No Results Available    5747
# Has Results               36
# Name: count, dtype: int64

# %%
sns.countplot(x='Study Results', data=data, palette = 'bright', hue ='Study Results')
# Out:
# <Axes: xlabel='Study Results', ylabel='count'>

# %%
data.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
# Trial Status
data['Status'].value_counts().plot(kind='bar', title='Trial Status Distribution', figsize=(10,5))
plt.ylabel('Count')
plt.show()

# Age Distribution
data['Age'].value_counts().plot(kind='bar', title='Age Group Distribution', figsize=(10,5))
plt.ylabel('Count')
plt.show()

# Phases
data['Phases'].value_counts().plot(kind='bar', title='Clinical Trial Phases', figsize=(10,5))
plt.ylabel('Count')
plt.show()

# %%
# Convert to datetime
data['Start Date'] = pd.to_datetime(data['Start Date'], errors='coerce')

# Plot trials started per month
monthly = data['Start Date'].dt.to_period('M').value_counts().sort_index()
monthly.plot(kind='line', title='Trials Started Over Time', figsize=(12,6))
plt.ylabel('Number of Trials')
plt.show()

# %%
# Create the Country column from the Locations column
data['Country'] = data['Locations'].apply(
    lambda x: str(x).split(',')[-1].strip() if pd.notnull(x) else 'Unknown'
)

# %%
data['Country'].value_counts().head(10).plot(kind='bar', title='Top 10 Countries by Trial Count', figsize=(10,5))
plt.ylabel('Number of Trials')
plt.show()

# %%
data.to_csv('cleaned_covid_trials.csv', index=False)

# %% [markdown]
# ## 📌 Conclusion
#
# - Most clinical trials are either *Completed* or *Recruiting*, reflecting a high level of research activity throughout the pandemic.
# - Trials predominantly focus on *adult populations* and include participants of *all genders*, indicating inclusive study designs.
# - *Phase 2* and *Phase 3* trials make up the majority of those with known phases, signifying significant progress toward evaluating treatment efficacy and safety.
# - The *United States* and *France* emerged as major contributors to COVID-19 clinical research.
# - A sharp increase in trial registrations around mid-2020 coincided with the global response to the pandemic’s first wave.
# - Data preprocessing included imputing missing values and dropping columns with excessive missingness; for skewed fields like Enrollment, the median was used to ensure robustness.
